# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Admin\\Desktop\\Ayurveda\\notebook\\data\\prediab.csv")
df
# Out:
#      Prediabetes Status  Age  Gender   BMI  Waist Circumference (cm)  \
# 0                     0   48  Female  24.5                        88
# 1                     1   51    Male  30.2                       102
# 2                     0   39  Female  22.1                        82
# 3                     1   58    Male  28.7                        98
# 4                     0   42  Female  25.4                        87
# ..                  ...  ...     ...   ...                       ...
# 160                   1   36  Female  26.2                        89
# 161                   1   63    Male  30.8                       103
# 162                   0   24  Female  22.7                        77
# 163                   1   69    Male  35.1                       113
# 164                   1   43  Female  28.5                        96
#
#     Physical Activity Level Frequent Urination Increased Thirst  \
# 0                  Moderate                 No               No
# 1                 Sedentary                Yes              Yes
# 2                    Active                 No               No
# 3                 Sedentary                Yes               No
# 4                  Moderate                 No               No
# ..                      ...                ...              ...
# 160                  Active                 No               No
# 161               Sedentary                 No              Yes
# 162                  Active                 No               No
# 163          Light Activity                Yes              Yes
# 164                Moderate                 No              Yes
#
#     Increased Hunger Excessive Weight Loss (Past 6 Months)  ... Dry Mouth  \
# 0                 No                                    No  ...        No
# 1                Yes                                    No  ...       Yes
# 2                 No                                    No  ...        No
# 3                Yes                                    No  ...       Yes
# 4       Occasionally                                    No  ...        No
# ..               ...                                   ...  ...       ...
# 160               No                                    No  ...        No
# 161              Yes                                    No  ...       Yes
# 162               No                                    No  ...        No
# 163              Yes                                    No  ...       Yes
# 164               No                                    No  ...        No
#
#     Tingling/Numbness in Hands/Feet Frequent Skin Infections (Past Year)  \
# 0                                No                                   No
# 1                                No                                   No
# 2                                No                                   No
# 3                                No                                   No
# 4                                No                                   No
# ..                              ...                                  ...
# 160                              No                                   No
# 161                              No                                   No
# 162                              No                                   No
# 163                              No                                  Yes
# 164                              No                                   No
#
#     Darkening Skin Folds (In Armpits/Neck) Difficulty Concentrating  \
# 0                                       No                       No
# 1                                       No                      Yes
# 2                                       No                       No
# 3                                       No                      Yes
# 4                                       No                       No
# ..                                     ...                      ...
# 160                                     No                       No
# 161                                     No                      Yes
# 162                                     No                       No
# 163                                     No                      Yes
# 164                                     No                       No
#
#     Irritability Erectile Dysfunction (Male) / Irregular Periods (Female)  \
# 0             No                                                 No
# 1            Yes                                                Yes
# 2            Yes                                                 No
# 3            Yes                                                Yes
# 4             No                                                 No
# ..           ...                                                ...
# 160          Yes                                                Yes
# 161          Yes                                                Yes
# 162           No                                                Yes
# 163          Yes                                                Yes
# 164          Yes                                                Yes
#
#     Delayed Wound Healing (After Minor Injury) Poor Night Sleep  \
# 0                                           No               No
# 1                                          Yes              Yes
# 2                                           No               No
# 3                                          NaN              Yes
# 4                                           No               No
# ..                                         ...              ...
# 160                                         No               No
# 161                                        Yes              Yes
# 162                                         No               No
# 163                                        Yes              Yes
# 164                                         No               No
#
#     Increased Belly Fat
# 0                   Yes
# 1                   Yes
# 2                   Yes
# 3                   Yes
# 4                   Yes
# ..                  ...
# 160                 Yes
# 161                 Yes
# 162                  No
# 163                 Yes
# 164                 Yes
#
# [165 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Prediabetes Status', 'Age', 'Gender', 'BMI',
#        'Waist Circumference (cm)', 'Physical Activity Level',
#        'Frequent Urination', 'Increased Thirst', 'Increased Hunger',
#        'Excessive Weight Loss (Past 6 Months)', 'Blurred Vision (Recent)',
#        'Fatigue', 'Slow Healing Wounds (Past 3 Months)', 'Dry Mouth',
#        'Tingling/Numbness in Hands/Feet',
#        'Frequent Skin Infections (Past Year)',
#        'Darkening Skin Folds (In Armpits/Neck)', 'Difficulty Concentrating',
#        'Irritability',
#        'Erectile Dysfunction (Male) / Irregular Periods (Female)',
#        'Delayed Wound Healing (After Minor Injury)', 'Poor Night Sleep',
#        'Increased Belly Fat'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 23

# %%
df.dropna(inplace=True)
df
# Out:
#      Prediabetes Status  Age  Gender   BMI  Waist Circumference (cm)  \
# 0                     0   48  Female  24.5                        88
# 1                     1   51    Male  30.2                       102
# 2                     0   39  Female  22.1                        82
# 4                     0   42  Female  25.4                        87
# 6                     0   35  Female  21.8                        78
# ..                  ...  ...     ...   ...                       ...
# 160                   1   36  Female  26.2                        89
# 161                   1   63    Male  30.8                       103
# 162                   0   24  Female  22.7                        77
# 163                   1   69    Male  35.1                       113
# 164                   1   43  Female  28.5                        96
#
#     Physical Activity Level Frequent Urination Increased Thirst  \
# 0                  Moderate                 No               No
# 1                 Sedentary                Yes              Yes
# 2                    Active                 No               No
# 4                  Moderate                 No               No
# 6                    Active                 No               No
# ..                      ...                ...              ...
# 160                  Active                 No               No
# 161               Sedentary                 No              Yes
# 162                  Active                 No               No
# 163          Light Activity                Yes              Yes
# 164                Moderate                 No              Yes
#
#     Increased Hunger Excessive Weight Loss (Past 6 Months)  ... Dry Mouth  \
# 0                 No                                    No  ...        No
# 1                Yes                                    No  ...       Yes
# 2                 No                                    No  ...        No
# 4       Occasionally                                    No  ...        No
# 6                 No                                    No  ...        No
# ..               ...                                   ...  ...       ...
# 160               No                                    No  ...        No
# 161              Yes                                    No  ...       Yes
# 162               No                                    No  ...        No
# 163              Yes                                    No  ...       Yes
# 164               No                                    No  ...        No
#
#     Tingling/Numbness in Hands/Feet Frequent Skin Infections (Past Year)  \
# 0                                No                                   No
# 1                                No                                   No
# 2                                No                                   No
# 4                                No                                   No
# 6                                No                                   No
# ..                              ...                                  ...
# 160                              No                                   No
# 161                              No                                   No
# 162                              No                                   No
# 163                              No                                  Yes
# 164                              No                                   No
#
#     Darkening Skin Folds (In Armpits/Neck) Difficulty Concentrating  \
# 0                                       No                       No
# 1                                       No                      Yes
# 2                                       No                       No
# 4                                       No                       No
# 6                                       No                       No
# ..                                     ...                      ...
# 160                                     No                       No
# 161                                     No                      Yes
# 162                                     No                       No
# 163                                     No                      Yes
# 164                                     No                       No
#
#     Irritability Erectile Dysfunction (Male) / Irregular Periods (Female)  \
# 0             No                                                 No
# 1            Yes                                                Yes
# 2            Yes                                                 No
# 4             No                                                 No
# 6             No                                                 No
# ..           ...                                                ...
# 160          Yes                                                Yes
# 161          Yes                                                Yes
# 162           No                                                Yes
# 163          Yes                                                Yes
# 164          Yes                                                Yes
#
#     Delayed Wound Healing (After Minor Injury) Poor Night Sleep  \
# 0                                           No               No
# 1                                          Yes              Yes
# 2                                           No               No
# 4                                           No               No
# 6                                           No               No
# ..                                         ...              ...
# 160                                         No               No
# 161                                        Yes              Yes
# 162                                         No               No
# 163                                        Yes              Yes
# 164                                         No               No
#
#     Increased Belly Fat
# 0                   Yes
# 1                   Yes
# 2                   Yes
# 4                   Yes
# 6                   Yes
# ..                  ...
# 160                 Yes
# 161                 Yes
# 162                  No
# 163                 Yes
# 164                 Yes
#
# [150 rows x 23 columns]

# %%
df.head()
# Out:
#    Prediabetes Status  Age  Gender   BMI  Waist Circumference (cm)  \
# 0                   0   48  Female  24.5                        88
# 1                   1   51    Male  30.2                       102
# 2                   0   39  Female  22.1                        82
# 4                   0   42  Female  25.4                        87
# 6                   0   35  Female  21.8                        78
#
#   Physical Activity Level Frequent Urination Increased Thirst  \
# 0                Moderate                 No               No
# 1               Sedentary                Yes              Yes
# 2                  Active                 No               No
# 4                Moderate                 No               No
# 6                  Active                 No               No
#
#   Increased Hunger Excessive Weight Loss (Past 6 Months)  ... Dry Mouth  \
# 0               No                                    No  ...        No
# 1              Yes                                    No  ...       Yes
# 2               No                                    No  ...        No
# 4     Occasionally                                    No  ...        No
# 6               No                                    No  ...        No
#
#   Tingling/Numbness in Hands/Feet Frequent Skin Infections (Past Year)  \
# 0                              No                                   No
# 1                              No                                   No
# 2                              No                                   No
# 4                              No                                   No
# 6                              No                                   No
#
#   Darkening Skin Folds (In Armpits/Neck) Difficulty Concentrating  \
# 0                                     No                       No
# 1                                     No                      Yes
# 2                                     No                       No
# 4                                     No                       No
# 6                                     No                       No
#
#   Irritability Erectile Dysfunction (Male) / Irregular Periods (Female)  \
# 0           No                                                 No
# 1          Yes                                                Yes
# 2          Yes                                                 No
# 4           No                                                 No
# 6           No                                                 No
#
#   Delayed Wound Healing (After Minor Injury) Poor Night Sleep  \
# 0                                         No               No
# 1                                        Yes              Yes
# 2                                         No               No
# 4                                         No               No
# 6                                         No               No
#
#   Increased Belly Fat
# 0                 Yes
# 1                 Yes
# 2                 Yes
# 4                 Yes
# 6                 Yes
#
# [5 rows x 23 columns]

# %%
ls=['Gender','Physical Activity Level','Frequent Urination', 'Increased Thirst', 'Increased Hunger',
       'Excessive Weight Loss (Past 6 Months)', 'Blurred Vision (Recent)',
       'Fatigue', 'Slow Healing Wounds (Past 3 Months)', 'Dry Mouth',
       'Tingling/Numbness in Hands/Feet',
       'Frequent Skin Infections (Past Year)',
       'Darkening Skin Folds (In Armpits/Neck)', 'Difficulty Concentrating',
       'Irritability',
       'Erectile Dysfunction (Male) / Irregular Periods (Female)',
       'Delayed Wound Healing (After Minor Injury)', 'Poor Night Sleep',
       'Increased Belly Fat']
for i in ls:
    print(i,df[i].unique())
# Out:
# Gender ['Female' 'Male']
# Physical Activity Level ['Moderate' 'Sedentary' 'Active' 'Light Activity' 'Inactive' 'Very Active']
# Frequent Urination ['No' 'Yes' 'Occasionally']
# Increased Thirst ['No' 'Yes']
# Increased Hunger ['No' 'Yes' 'Occasionally']
# Excessive Weight Loss (Past 6 Months) ['No' 'Yes']
# Blurred Vision (Recent) ['No' 'Yes']
# Fatigue ['Occasionally' 'Yes' 'No']
# Slow Healing Wounds (Past 3 Months) ['No' 'Yes' 'Occasionally']
# Dry Mouth ['No' 'Yes' 'Sometimes']
# Tingling/Numbness in Hands/Feet ['No' 'Yes']
# Frequent Skin Infections (Past Year) ['No' 'Yes']
# Darkening Skin Folds (In Armpits/Neck) ['No' 'Yes']
# Difficulty Concentrating ['No' 'Yes']
# Irritability ['No' 'Yes' 'Occasionally']
# Erectile Dysfunction (Male) / Irregular Periods (Female) ['No' 'Yes']
# Delayed Wound Healing (After Minor Injury) ['No' 'Yes']
# Poor Night Sleep ['No' 'Yes' 'Occasionally']
# Increased Belly Fat ['Yes' 'No']

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame
columns_ls = ['Gender','Frequent Urination', 'Increased Thirst', 'Increased Hunger',
       'Excessive Weight Loss (Past 6 Months)', 'Blurred Vision (Recent)',
       'Fatigue', 'Slow Healing Wounds (Past 3 Months)', 'Dry Mouth',
       'Tingling/Numbness in Hands/Feet',
       'Frequent Skin Infections (Past Year)',
       'Darkening Skin Folds (In Armpits/Neck)', 'Difficulty Concentrating',
       'Irritability',
       'Erectile Dysfunction (Male) / Irregular Periods (Female)',
       'Delayed Wound Healing (After Minor Injury)', 'Poor Night Sleep',
       'Increased Belly Fat']

label_encoders = {}
for i in columns_ls:
    label_encoders[i] = LabelEncoder()
    df[i] = label_encoders[i].fit_transform(df[i])

# %%
df['Physical Activity Level'].unique()
# Out:
# array(['Moderate', 'Sedentary', 'Active', 'Light Activity', 'Inactive',
#        'Very Active'], dtype=object)

# %%
encoding_mapping = {'Active': 3, 'Very Active': 3, 'Moderate': 2, 'Light Activity': 2, 'Sedentary': 1, 'Inactive': 1}
df['Physical Activity Level'] = df['Physical Activity Level'].map(encoding_mapping)

# %%
ls=['Gender','Physical Activity Level','Frequent Urination', 'Increased Thirst', 'Increased Hunger',
       'Excessive Weight Loss (Past 6 Months)', 'Blurred Vision (Recent)',
       'Fatigue', 'Slow Healing Wounds (Past 3 Months)', 'Dry Mouth',
       'Tingling/Numbness in Hands/Feet',
       'Frequent Skin Infections (Past Year)',
       'Darkening Skin Folds (In Armpits/Neck)', 'Difficulty Concentrating',
       'Irritability',
       'Erectile Dysfunction (Male) / Irregular Periods (Female)',
       'Delayed Wound Healing (After Minor Injury)', 'Poor Night Sleep',
       'Increased Belly Fat']
for i in ls:
    print(i,df[i].unique())
# Out:
# Gender [0 1]
# Physical Activity Level [2 1 3]
# Frequent Urination [0 2 1]
# Increased Thirst [0 1]
# Increased Hunger [0 2 1]
# Excessive Weight Loss (Past 6 Months) [0 1]
# Blurred Vision (Recent) [0 1]
# Fatigue [1 2 0]
# Slow Healing Wounds (Past 3 Months) [0 2 1]
# Dry Mouth [0 2 1]
# Tingling/Numbness in Hands/Feet [0 1]
# Frequent Skin Infections (Past Year) [0 1]
# Darkening Skin Folds (In Armpits/Neck) [0 1]
# Difficulty Concentrating [0 1]
# Irritability [0 2 1]
# Erectile Dysfunction (Male) / Irregular Periods (Female) [0 1]
# Delayed Wound Healing (After Minor Injury) [0 1]
# Poor Night Sleep [0 2 1]
# Increased Belly Fat [1 0]

# %%
def remove_outliers(dataframe, columns):
    for column in columns:
        q1 = dataframe[column].quantile(0.25)
        q3 = dataframe[column].quantile(0.75)
        IQR = q3 - q1
        lower_bound = q1 - 1.5 * IQR
        upper_bound = q3 + 1.5 * IQR
        dataframe = dataframe[(dataframe[column] >= lower_bound) & (dataframe[column] <= upper_bound)]
    
    return dataframe
columns=['Prediabetes Status', 'Age', 'Gender', 'BMI',
       'Waist Circumference (cm)', 'Physical Activity Level',
       'Frequent Urination', 'Increased Thirst', 'Increased Hunger',
       'Excessive Weight Loss (Past 6 Months)', 'Blurred Vision (Recent)',
       'Fatigue', 'Slow Healing Wounds (Past 3 Months)', 'Dry Mouth',
       'Tingling/Numbness in Hands/Feet',
       'Frequent Skin Infections (Past Year)',
       'Darkening Skin Folds (In Armpits/Neck)', 'Difficulty Concentrating',
       'Irritability',
       'Erectile Dysfunction (Male) / Irregular Periods (Female)',
       'Delayed Wound Healing (After Minor Injury)', 'Poor Night Sleep',
       'Increased Belly Fat']
df=remove_outliers(df, columns)
df
# Out:
#      Prediabetes Status  Age  Gender   BMI  Waist Circumference (cm)  \
# 33                    0   49       0  28.5                        96
# 37                    0   29       0  24.7                        82
# 39                    0   34       0  21.2                        74
# 41                    0   25       0  22.5                        78
# 43                    0   27       0  23.1                        80
# ..                  ...  ...     ...   ...                       ...
# 156                   0   41       0  24.6                        84
# 158                   0   20       0  19.8                        68
# 160                   1   36       0  26.2                        89
# 162                   0   24       0  22.7                        77
# 164                   1   43       0  28.5                        96
#
#      Physical Activity Level  Frequent Urination  Increased Thirst  \
# 33                         2                   1                 0
# 37                         3                   0                 0
# 39                         3                   0                 0
# 41                         3                   0                 0
# 43                         3                   0                 0
# ..                       ...                 ...               ...
# 156                        3                   0                 0
# 158                        3                   0                 0
# 160                        3                   0                 0
# 162                        3                   0                 0
# 164                        2                   0                 1
#
#      Increased Hunger  Excessive Weight Loss (Past 6 Months)  ...  Dry Mouth  \
# 33                  0                                      0  ...          0
# 37                  0                                      0  ...          0
# 39                  0                                      0  ...          0
# 41                  0                                      0  ...          0
# 43                  0                                      0  ...          0
# ..                ...                                    ...  ...        ...
# 156                 0                                      0  ...          0
# 158                 0                                      0  ...          0
# 160                 0                                      0  ...          0
# 162                 0                                      0  ...          0
# 164                 0                                      0  ...          0
#
#      Tingling/Numbness in Hands/Feet  Frequent Skin Infections (Past Year)  \
# 33                                 0                                     0
# 37                                 0                                     0
# 39                                 0                                     0
# 41                                 0                                     0
# 43                                 0                                     0
# ..                               ...                                   ...
# 156                                0                                     0
# 158                                0                                     0
# 160                                0                                     0
# 162                                0                                     0
# 164                                0                                     0
#
#      Darkening Skin Folds (In Armpits/Neck)  Difficulty Concentrating  \
# 33                                        0                         0
# 37                                        0                         0
# 39                                        0                         0
# 41                                        0                         0
# 43                                        0                         0
# ..                                      ...                       ...
# 156                                       0                         0
# 158                                       0                         0
# 160                                       0                         0
# 162                                       0                         0
# 164                                       0                         0
#
#      Irritability  Erectile Dysfunction (Male) / Irregular Periods (Female)  \
# 33              2                                                  1
# 37              0                                                  1
# 39              0                                                  1
# 41              0                                                  1
# 43              0                                                  1
# ..            ...                                                ...
# 156             0                                                  1
# 158             0                                                  1
# 160             2                                                  1
# 162             0                                                  1
# 164             2                                                  1
#
#      Delayed Wound Healing (After Minor Injury)  Poor Night Sleep  \
# 33                                            0                 0
# 37                                            0                 0
# 39                                            0                 0
# 41                                            0                 0
# 43                                            0                 0
# ..                                          ...               ...
# 156                                           0                 0
# 158                                           0                 0
# 160                                           0                 0
# 162                                           0                 0
# 164                                           0                 0
#
#      Increased Belly Fat
# 33                     1
# 37                     1
# 39                     0
# 41                     0
# 43                     0
# ..                   ...
# 156                    0
# 158                    0
# 160                    1
# 162                    0
# 164                    1
#
# [68 rows x 23 columns]

# %%
df['Prediabetes Status'].value_counts()
# Out:
# Prediabetes Status
# 0    48
# 1    20
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Age', 'BMI', 'Waist Circumference (cm)']] = scaler.fit_transform(df[['Age', 'BMI', 'Waist Circumference (cm)']])

# %%
df.to_csv('encoded_data.csv', index=False)

# %%
df1=pd.read_csv('encoded_data.csv')

# %%
df1['Prediabetes Status'].value_counts()
# Out:
# Prediabetes Status
# 0    48
# 1    20
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
x = df1.drop('Prediabetes Status', axis=1)
y = df1['Prediabetes Status']


smote = SMOTE(random_state=42)
x_amplified, y_amplified = smote.fit_resample(x, y)

# %%
y_amplified.value_counts()
# Out:
# Prediabetes Status
# 0    48
# 1    48
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_amplified, y_amplified, test_size=0.2, random_state=42)

# Train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

# Make predictions on the training and test sets
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Precision, recall, and F1-score for training data
train_precision = precision_score(y_train, train_predictions)
train_recall = recall_score(y_train, train_predictions)
train_f1_score = f1_score(y_train, train_predictions)
train_accuracy = model.score(X_train, y_train)



# Precision, recall, and F1-score for test data
test_precision = precision_score(y_test, test_predictions)
test_recall = recall_score(y_test, test_predictions)
test_f1_score = f1_score(y_test, test_predictions)
test_accuracy = model.score(X_test, y_test)

# Confusion matrix for training data
train_conf_matrix = confusion_matrix(y_train, train_predictions)

# Confusion matrix for test data
test_conf_matrix = confusion_matrix(y_test, test_predictions)

# Print evaluation metrics

print(f"Training Accuracy: {train_accuracy:.2f}")
print("Training Precision:", train_precision)
print("Training Recall:", train_recall)
print("Training F1-score:", train_f1_score)
print(f"Test Accuracy: {test_accuracy:.2f}")
print("\nTest Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test F1-score:", test_f1_score)
print("\nConfusion Matrix for Training Data:")
print(train_conf_matrix)
print("\nConfusion Matrix for Test Data:")
print(test_conf_matrix)
# Out:
# Training Accuracy: 0.89
# Training Precision: 0.9393939393939394
# Training Recall: 0.8378378378378378
# Training F1-score: 0.8857142857142858
# Test Accuracy: 0.85
#
# Test Precision: 0.9
# Test Recall: 0.8181818181818182
# Test F1-score: 0.8571428571428572
#
# Confusion Matrix for Training Data:
# [[37  2]
#  [ 6 31]]
#
# Confusion Matrix for Test Data:
# [[8 1]
#  [2 9]]

# %%
import numpy as np

new_data_point = np.array([[45, 1, 28.5, 95, 3, 0, 1, 0, 0, 0, 1, 0, 0, 1, 0,1,0, 0, 0, 0, 0, 1]])

prediction = model.predict(new_data_point)

if prediction==1:
    print("You are Type-2 Pre-diabetic")
else:
   print("You are not a Type-2 Pre-diabetic")
# Out:
# You are Type-2 Pre-diabetic
# c:\Users\Admin\Desktop\Ayurveda\venv\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define accuracy for training and testing data
accuracy = [train_accuracy, test_accuracy]

# Define labels for the bars
labels = ['Training', 'Test']
x = np.arange(len(labels))

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))

# Plot bars for accuracy
bar_width = 0.4
bars = ax.bar(x, accuracy, width=bar_width, color=['blue', 'green'])

# Add labels, title, and legend
ax.set_xlabel('Dataset')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy for Training and Test Data')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(['Accuracy'])

# Function to add labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Add labels on top of each bar
add_labels(bars)

plt.show()

# %%
# Initialize a dictionary to store the mappings
label_mappings = {}

# Loop over each column, fit LabelEncoder, and save the mappings
for column in ls:
    le = LabelEncoder()
    le.fit(df[column])
    
    # Create a mapping dictionary for the current column
    label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    label_mappings[column] = label_mapping

# Display the mappings for each column
for column, mapping in label_mappings.items():
    print(f"Mappings for '{column}':")
    for original_value, encoded_value in mapping.items():
        print(f"  {original_value} -> {encoded_value}")
    print("\n")
# Out:
# Mappings for 'Gender':
#   0 -> 0
#   1 -> 1
#
#
# Mappings for 'Physical Activity Level':
#   2 -> 0
#   3 -> 1
#
#
# Mappings for 'Frequent Urination':
#   0 -> 0
#   1 -> 1
#   2 -> 2
#
#
# Mappings for 'Increased Thirst':
#   0 -> 0
#   1 -> 1
#
#
# Mappings for 'Increased Hunger':
#   0 -> 0
#   1 -> 1
#   2 -> 2
#
#
# Mappings for 'Excessive Weight Loss (Past 6 Months)':
#   0 -> 0
#
#
# Mappings for 'Blurred Vision (Recent)':
#   0 -> 0
#
#
# Mappings for 'Fatigue':
#   0 -> 0
#   1 -> 1
#   2 -> 2
#
#
# Mappings for 'Slow Healing Wounds (Past 3 Months)':
#   0 -> 0
#
#
# Mappings for 'Dry Mouth':
#   0 -> 0
#
#
# Mappings for 'Tingling/Numbness in Hands/Feet':
#   0 -> 0
#
#
# Mappings for 'Frequent Skin Infections (Past Year)':
#   0 -> 0
#
#
# Mappings for 'Darkening Skin Folds (In Armpits/Neck)':
#   0 -> 0
#
#
# Mappings for 'Difficulty Concentrating':
#   0 -> 0
#
#
# Mappings for 'Irritability':
#   0 -> 0
#   1 -> 1
#   2 -> 2
#
#
# Mappings for 'Erectile Dysfunction (Male) / Irregular Periods (Female)':
#   1 -> 0
#
#
# Mappings for 'Delayed Wound Healing (After Minor Injury)':
#   0 -> 0
#
#
# Mappings for 'Poor Night Sleep':
#   0 -> 0
#
#
# Mappings for 'Increased Belly Fat':
#   0 -> 0
#   1 -> 1
